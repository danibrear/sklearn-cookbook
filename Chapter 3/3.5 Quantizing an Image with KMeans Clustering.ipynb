# %%
# %matplotlib inline

# %%
# goal is to blur an image with clustering

# %%
from scipy import ndimage
import matplotlib.pyplot as plt

# %%
img = ndimage.imread("headshot.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (420, 420, 3)

# %%
# to quantize an image we need to convert it to a 2 dimensional
# matrix with length being Height x Width of the image and the
# rows of the matrix being the RGB values

# %%
x,y,z = img.shape

# %%
long_img = img.reshape(x*y,z)

# %%
long_img.shape
# Out:
# (176400, 3)

# %%
# we want 5 distinct colors so set n_clusters to 5
from sklearn import cluster

# %%
kmeans = cluster.KMeans(n_clusters=5)
kmeans.fit(long_img)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=5, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
centers = kmeans.cluster_centers_

# %%
centers
# Out:
# array([[ 195.88628098,  173.3467817 ,  150.45627167],
#        [  25.67240586,   21.24393088,   16.80314888],
#        [ 142.53247828,  206.08837402,  226.04460074],
#        [  88.01184522,   70.30459517,   55.23440334],
#        [ 150.95989928,  134.02771882,  117.20789112]])

# %%
labe
